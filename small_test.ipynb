# %%
import numpy as np
from matplotlib import pyplot as plt

displacement = np.array([[-10, 10], [10, 10], [10, -10], [-10, -10]])

a = np.array([-2.4619,  1.5788,  1.6019,  1.5061,  1.8757,  1.6938, -2.0411,  1.8277,
        -2.2440, -1.9860,  1.6349, -1.7975,  2.0925, -2.0502, -2.0036, -2.0732])
a = a[0:16].reshape((-1, 2))
# a[0:4, :] = a[0:4, :] + displacement
# a[4:8, :] = a[4:8, :] + displacement
plt.scatter(a[:, 0], a[:, 1],)
# plt.scatter(a[2:4, 0], a[2:4, 1], c='b')
for i in range(8):
    plt.annotate(i, (a[i, 0], a[i, 1]))
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

displacement = np.array([[-10, 10], [10, 10], [10, -10], [-10, -10]])

a = np.array([17.7936,  20.6306,   9.5849,  23.0542, -17.5702,  22.9533,  -7.5162,
         20.7577,  17.8646, -23.1129,   9.4224, -23.4501, -17.7102, -23.7093,
         -7.6268, -23.0253])
a = a[0:16].reshape((-1, 2))
# a[0:4, :] = a[0:4, :] + displacement
# a[4:8, :] = a[4:8, :] + displacement
plt.scatter(a[:, 0], a[:, 1],)
# plt.scatter(a[2:4, 0], a[2:4, 1], c='b')
for i in range(8):
    plt.annotate(i, (a[i, 0], a[i, 1]))
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

a = np.array([-5.6762,  4.6336,  5.9066,  4.4367,  6.5510,  6.1829, -6.4002,  6.3430,
        -5.3960, -6.4369,  6.1007, -6.5781,  6.5559, -6.1764, -6.4912, -6.4109])
a = a[0:16].reshape((-1, 2))
plt.scatter(a[:, 0], a[:, 1],)
# plt.scatter(a[2:4, 0], a[2:4, 1], c='b')
for i in range(8):
    plt.annotate(i, (a[i, 0], a[i, 1]))
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

a = np.array([ -3.8326,  14.2277,  -4.6626,  14.0079,   6.0477,  15.1734,   5.5329,
         15.0951,  -4.1972, -17.3612,  -4.5490, -17.3703,   6.0790, -17.5483,
          5.1569, -17.5989])
a = a.reshape((8, 2))
plt.scatter(a[:, 0], a[:, 1])
plt.show()
